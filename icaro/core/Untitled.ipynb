# %%
import pandas as pd
import numpy as np
import matplotlib as mp
import matplotlib.pylab as plt
from pandas.tseries.offsets import Day, Minute

# %matplotlib inline


plt.rcParams["figure.figsize"]          = 30, 15
plt.rcParams["font.size"]               = 15
plt.rcParams["figure.max_open_warning"] = 100

profOpt = "--k"
fitOpt  = "r"

# %%
np.random.seed(10)
dates = pd.date_range("1/1/2001", "1/5/2004")
y = np.random.randn(len(dates)).cumsum()

fig, ax = plt.subplots()
ax.plot(dates, y)

x_loc = pd.to_datetime(["6/5/2001", "7/1/2003"])
ymin, ymax = ax.get_ylim()
ax.vlines(x_loc, ymin, ymax, lw = 2, linestyle = "--")
for x, y, z in zip(x_loc, [10,15], np.array([Day(20),Day(30)])):
    ax.errorbar(x, y, xerr = z)

# %%
Minute(360)+Minute(25)+Day(2)
# Out:
# <3265 * Minutes>

# %%
np.array([Day(20.8),Day(30)])
# Out:
# array([<20 * Days>, <30 * Days>], dtype=object)

# %%
pd.to_datetime(["6/5/2001", "7/1/2003"])
# Out:
# DatetimeIndex(['2001-06-05', '2003-07-01'], dtype='datetime64[ns]', freq=None)

# %%
pd.to_datetime(["6/5/2001", "7/1/2003"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-5e7a780f65dd> in <module>()
# ----> 1 pd.to_datetime(["6/5/2001", "7/1/2003"])(0)
#
# TypeError: 'DatetimeIndex' object is not callable

# %%
print('asjdfashdfkasd'+input())
# Out:
# 'pr'
# asjdfashdfkasd'pr'
