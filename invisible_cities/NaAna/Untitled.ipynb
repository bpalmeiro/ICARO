# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
plt.rcParams["figure.figsize"]          = 8, 6
plt.rcParams["font.size"]               = 15
plt.rcParams["figure.max_open_warning"] = 100

# %%
runs = [3614, 3740,3752,3755,3757,3761,3768,3770,3773,3783,3787,3789,3791,3794,3890,3898,3901,3904]


x    = [3614, 3740,3752,3755,3890,3898,3901,3898,3904]
xrc  = [7, 15]
exc  = [6.5, 1.5]
xr   = [   0,    1,   2,   3,  14,  15,  16,  17]
ex   = [ 0.5,  0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5]
y1   = [1.09,    1,1.17,1.36,0.77,0.91,0.91,0.76]
y1c  = [1.2,0.86]
ey1  = [.038, .058,.040,.047,.034,.038,.029,.035]
ey1c = [.021,.022]
y2   = [1.03,  0.9,1.08,0.96,0.68,0.85,0.76,0.72]
y2c  = [1.02,0.76]
ey2  = [.034, .050,.033,.064,.017,.045,.015,.058]
ey2c = [.018,.017]

# %%
plt.plot(range(len(runs)),[-1]*len(runs))
plt.xticks(range(len(runs)),runs,rotation='vertical',fontsize=12)
plt.ylim(0.6,1.6)
plt.xlim(-.5,17.5)
plt.errorbar(xr, y1,yerr=ey1, xerr=ex, fmt='o', label='R<180', color='b')
plt.errorbar(xr, y2,yerr=ey2, xerr=ex, fmt='o', label='R<100', color='g')
plt.errorbar(xrc, y1c,yerr=ey1c, xerr=exc, fmt='s', label='R<180', color='r')
plt.errorbar(xrc, y2c,yerr=ey2c, xerr=exc, fmt='s', label='R<100', color='k')
plt.grid()
plt.legend(loc=9)
plt.xlabel('Run',fontsize=16)
plt.ylabel('Res @ Qbb',fontsize=16)

plt.fill_between([-0.5,.5  ],[2,2], color='grey'  , alpha='0.5')
plt.fill_between([ 0.5,5.5 ],[2,2], color='yellow', alpha='0.3')
plt.fill_between([ 5.5,8.5 ],[2,2], color='yellow', alpha='0.4')
plt.fill_between([ 8.5,13.5],[2,2], color='yellow', alpha='0.5')
plt.fill_between([13.5,14.5],[2,2], color='yellow', alpha='0.6')
plt.fill_between([14.5,16.5],[2,2], color='yellow', alpha='0.8')
plt.fill_between([16.5,17.5],[2,2], color='grey'  , alpha='0.5')
plt.text(-0.12,0.825,'S2 trigger', fontsize=15,rotation='vertical')
plt.text(-0.12,1.4 ,'273 V/cm', fontsize=15,rotation='vertical')
plt.text(1.5,0.7,'S1 trigger \n 273 V/cm', fontsize=15)#,rotation='vertical')
plt.text(5.55,0.7,'S1 trigger \n 291 V/cm', fontsize=14.5)#,rotation='vertical')
plt.text(9.5,0.7,'S1 trigger \n 309 V/cm', fontsize=15)#,rotation='vertical')
plt.text(13.75,1.4,'S1 trigger 346 V/cm', fontsize=15,rotation='vertical')
plt.text(15.35,1.4,'S1 trigger 364 V/cm', fontsize=15,rotation='vertical')
plt.text(16.85,1.4,'S2 trigger 364 V/cm', fontsize=15,rotation='vertical')
plt.show()

# %%
lftale = [(3628, 322.74384601863659, 0.23703634514118099),
 (3645, 472.81228027561514, 2.1388161148424767),
 (3715, 508.58406882297669, 0.66459517105472643),
 (3724, 509.9168334156999, 3.9220335210232173),
 (3733, 483.5264601715009, 9.247249142758017),
 (3741, 541.78140900434403, 1.1159143107471934),
 (3753, 424.86088678206607, 6.7263726222364086),
 (3756, 400.73939652671743, 2.6485999224782022),
 (3758, 432.71751020815981, 0.18840908372544199),
 (3762, 480.87663976186718, 11.400103892624074),
 (3767, 436.87319354201162, 5.4504900139519838),
 (3769, 532.9620700541476, 9.6586854510605491),
 (3772, 423.06163243866501, 5.6594254315951824),
 (3774, 409.41792334313601, 4.0097046656318298),
 (3782, 530.89702155392524, 2.9461520557564898),
 (3784, 455.48284519637252, 8.008097360548426),
 (3788, 467.86438961120678, 23.669791085537593),
 (3790, 457.31866595972514, 16.53662530190854),
 (3793, 504.9175553321428, 3.6187841007160011),
 (3795, 503.67353858012717, 10.105685812682676),
 (3822, 526.02621790930664, 15.612153702927772),
 (3824, 526.90338440335893, 19.875533229956027),
 (3826, 541.99805885736168, 16.852585411249841),
 (3829, 535.7118929658842, 3.7693897347484722),
 (3883, 524.96290860254999, 12.655523717477493),
 (3888, 579.57297935487043, 9.3268169442283622),
 (3897, 582.44562452290779, 13.699085703246043),
 (3900, 586.5500095015899, 18.571227362735911),
 (3903, 536.77434639536818, 20.296304188367781),
 (3905, 631.17944375086518, 19.6964067715796)]

# %%
lftale = np.array(lftale)
runs= lftale[:,0]
lifetimes = lftale[:,1]
elambdas = lftale[:,2]

# %%
x = ['3614','3740', '3752', '3755', '3757', '3761', '3768', '3770', '3773', '3783', '3787', '3789', '3791', 
     '3794', '3890','3898', '3901','3904']
y = [-425.24950843,-643.96729317034442, -492.53550037180798, -396.91698350704098, -386.86432708674585,
     -516.73628833670841, -535.65923755918141, -405.88782627390498, -477.89041243912834, -577.22166631606387, 
     -557.81100493644726, -492.9976926364422, -510.81643014298078, -509.3820397302772, -699.27804809562838,
     -686.41846971, -762.31254999, -733.67958641]
ey = [15,55.128577138302994, 17.965579245953037, 24.732037557977428, 15.519666579725245, 27.739012880489408,
      25.394752373885954, 18.726253802956425, 23.165913351727148, 38.216308788517409, 45.885408667456581,
      36.133451572783763, 34.62864229875904, 54.692747054917454, 71.952909944287228, 71, 66, 32]

# %%
a = [ -577.22166631606387, -557.81100493644726, -492.9976926364422, -510.81643014298078, -509.3820397302772]
b = [38.216308788517409, 45.885408667456581, 36.133451572783763, 34.62864229875904, 54.692747054917454]

# %%
print(np.average(np.array(a), weights=np.array(b)))
b = np.array(b)
print(np.sum(b**2)**0.5)
# Out:
# -529.769905377
# 95.1946571843

# %%
eyn = np.array(ey)
a = plt.errorbar(range(len(x)),abs(np.array(y)),eyn, marker='o', color='b')
plt.xticks(range(len(x)),x,rotation='vertical')
plt.xlabel('run')
plt.ylabel('electron liftime ($\mu$ s)')
plt.show()

# %%
eyn = np.array(ey)
xn  = np.array(x,dtype=np.float)
yn  = abs(np.array(y))
a = plt.errorbar(xn,yn,eyn,marker='o', color='g')
b = plt.errorbar(runs,lifetimes,elambdas,marker='o', color='b')

locs, labels = plt.xticks()
plt.legend(["Na22 XR", "alphas"], loc=2)
plt.setp(labels, rotation=90)
plt.xlabel('run')
plt.ylabel('electron liftime ($\mu$ s)')
plt.show()

# %%
-529.769905377
95.1946571843

# %%
lft   = [-425.24950843, -643.96729317, -492.53550037, -396.91698351, -709.92569658, -728.88574314, -733.67958641, -470.57, -529.77]
elft  = [15.          ,  55          ,  18.         ,  25.         ,  72          ,  24          ,  32.         ,  49    , 95]
res   = [1.09         ,  1.          ,  1.17        ,  1.36        ,  0.77        ,  0.87        ,  0.76        ,  1.12  , 1.16]
eres  = [0.038        ,  0.058       ,  0.04        ,  0.047       ,  0.034       ,  0.022       ,  0.035       ,  0.092 , 0.031]
resc  = [1.03         ,  0.9         ,  1.08        ,  0.96        ,  0.68        ,  0.76        ,  0.7         ,  0.99  , 1.]
eresc = [0.034        ,  0.058       ,  0.033       ,  0.064       ,  0.017       ,  0.017       ,  0.058       ,  0.068 , 0.033]

# %%
xn  = np.abs(np.array(lft,dtype=np.float))
exn = np.array(elft)
yn  = np.array(res)
eyn = np.array(eres)
a = plt.errorbar(xn,yn,eyn,exn, fmt='o', color='g')
locs, labels = plt.xticks()
plt.legend(["Na22 XR", "alphas"], loc=0)
plt.setp(labels, rotation=0)
plt.xlabel('electron liftime ($\mu$ s)')
plt.ylabel('res @ Qbb')
plt.show()

# %%
xn  = np.abs(np.array(lft,dtype=np.float))
exn = np.array(elft)
yn  = np.array(resc)
eyn = np.array(eresc)
a = plt.errorbar(xn,yn,eyn,exn, fmt='o', color='g')
locs, labels = plt.xticks()
plt.legend(["Na22 XR", "alphas"], loc=0)
plt.setp(labels, rotation=0)
plt.xlabel('electron liftime ($\mu$ s)')
plt.ylabel('res @ Qbb')
plt.show()

# %%
dfv   = [272.7, 272.7, 272.7, 272.7, 345.5, 363.6, 363.6 , 290.9, 309.1]
edfv  = [0    , 0    , 0    , 0.   , 0    , 0    , 0.    , 0    , 0]
res   = [1.09 , 1.   , 1.17 , 1.36 , 0.77 , 0.87 , 0.76  , 1.12 , 1.16]
eres  = [0.038, 0.058, 0.04 , 0.047, 0.034, 0.022, 0.035 , 0.092, 0.031]
resc  = [1.03 , 0.9  , 1.08 , 0.96 , 0.68 , 0.76 , 0.7   , 0.99 , 1.]
eresc = [0.034, 0.058, 0.033, 0.064, 0.017, 0.017, 0.058 , 0.065, 0.033]

# %%
xn  = np.abs(np.array(dfv,dtype=np.float))
exn = np.array(edfv)
yn  = np.array(resc)
eyn = np.array(eresc)
a = plt.errorbar(xn,yn,eyn,exn, fmt='o', color='g')
locs, labels = plt.xticks()
plt.legend(["Na22 XR", "alphas"], loc=0)
plt.setp(labels, rotation=0)
plt.xlabel('electron liftime ($\mu$ s)')
plt.ylabel('res @ Qbb')
plt.show()
